# %%
from rve_redux import RVE

ff = 0.4
r_f = 7e-6   # fiber radius [m]
# l_min = 1e-8 * scale_factor
delta = 50 * r_f
L = delta
# a_sq = L ** 2  # square area of the window taken
lc = L/300
name = 'rve'
nu = 0.3
rve = RVE(ff, r_f, L, lc, name, nu, name)
# k_e = rve.k_elemental(1, 4)
# print(k_e)
# Out:
# Info    : Increasing process stack size (8192 kB < 16 MB)

# %%
rve.run()
# Out:
# -------------------------------------------------------
# Version       : 4.8.4
# License       : GNU General Public License
# Build OS      : Linux64-sdk
# Build date    : 20210428
# Build host    : gmsh.info
# Build options : 64Bit ALGLIB ANN Bamg Blas[petsc] Blossom Cgns DIntegration Dlopen DomHex Eigen Fltk Gmm Hxt Jpeg[fltk] Kbipack Lapack[petsc] LinuxJoystick MathEx Med Mesh Metis Mmg Mpeg Netgen ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OptHom PETSc Parser Plugins Png[fltk] Post QuadTri Solver TetGen/BR Voro++ Zlib[fltk]
# FLTK version  : 1.4.0
# PETSc version : 3.14.4 (real arithmtic)
# OCC version   : 7.6.0
# MED version   : 4.1.0
# Packaged by   : geuzaine
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------

# %%
rve.mesh()
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Line)
# Info    : [ 10%] Meshing curve 4 (Line)
# Info    : [ 10%] Meshing curve 5 (Circle)
# Info    : [ 10%] Meshing curve 6 (Circle)
# Info    : [ 10%] Meshing curve 7 (Circle)
# Info    : [ 10%] Meshing curve 8 (Circle)
# Info    : [ 10%] Meshing curve 9 (Circle)
# Info    : [ 10%] Meshing curve 10 (Circle)
# Info    : [ 10%] Meshing curve 11 (Circle)
# Info    : [ 10%] Meshing curve 12 (Circle)
# Info    : [ 10%] Meshing curve 13 (Circle)
# Info    : [ 10%] Meshing curve 14 (Circle)
# Info    : [ 10%] Meshing curve 15 (Circle)
# Info    : [ 10%] Meshing curve 16 (Circle)
# Info    : [ 10%] Meshing curve 17 (Circle)
# Info    : [ 10%] Meshing curve 18 (Circle)
# Info    : [ 10%] Meshing curve 19 (Circle)
# Info    : [ 10%] Meshing curve 20 (Circle)
# Info    : [ 10%] Meshing curve 21 (Circle)
# Info    : [ 10%] Meshing curve 22 (Circle)
# Info    : [ 10%] Meshing curve 23 (Circle)
# Info    : [ 10%] Meshing curve 24 (Circle)
# Info    : [ 10%] Meshing curve 25 (Circle)
# Info    : [ 10%] Meshing curve 26 (Circle)
# Info    : [ 10%] Meshing curve 27 (Circle)
# Info    : [ 10%] Meshing curve 28 (Circle)
# Info    : [ 10%] Meshing curve 29 (Circle)
# Info    : [ 10%] Meshing curve 30 (Circle)
# Info    : [ 10%] Meshing curve 31 (Circle)
# Info    : [ 20%] Meshing curve 32 (Circle)
# Info    : [ 20%] Meshing curve 33 (Circle)
# Info    : [ 20%] Meshing curve 34 (Circle)
# Info    : [ 20%] Meshing curve 35 (Circle)
# Info    : [ 20%] Meshing curve 36 (Circle)
# Info    : [ 20%] Meshing curve 37 (Circle)
# Info    : [ 20%] Meshing curve 38 (Circle)
# Info    : [ 20%] Meshing curve 39 (Circle)
# Info    : [ 20%] Meshing curve 40 (Circle)
# Info    : [ 20%] Meshing curve 41 (Circle)
# Info    : [ 20%] Meshing curve 42 (Circle)
# Info    : [ 20%] Meshing curve 43 (Circle)
# Info    : [ 20%] Meshing curve 44 (Circle)
# Info    : [ 20%] Meshing curve 45 (Circle)
# Info    : [ 20%] Meshing curve 46 (Circle)
# Info    : [ 20%] Meshing curve 47 (Circle)
# Info    : [ 20%] Meshing curve 48 (Circle)
# Info    : [ 20%] Meshing curve 49 (Circle)
# Info    : [ 20%] Meshing curve 50 (Circle)
# Info    : [ 20%] Meshing curve 51 (Circle)
# Info    : [ 20%] Meshing curve 52 (Circle)
# Info    : [ 20%] Meshing curve 53 (Circle)
# Info    : [ 20%] Meshing curve 54 (Circle)
# Info    : [ 20%] Meshing curve 55 (Circle)
# Info    : [ 20%] Meshing curve 56 (Circle)
# Info    : [ 20%] Meshing curve 57 (Circle)
# Info    : [ 20%] Meshing curve 58 (Circle)
# Info    : [ 20%] Meshing curve 59 (Circle)
# Info    : [ 20%] Meshing curve 60 (Circle)
# Info    : [ 20%] Meshing curve 61 (Circle)
# Info    : [ 30%] Meshing curve 62 (Circle)
# Info    : [ 30%] Meshing curve 63 (Circle)
# Info    : [ 30%] Meshing curve 64 (Circle)
# Info    : [ 30%] Meshing curve 65 (Circle)
# Info    : [ 30%] Meshing curve 66 (Circle)
# Info    : [ 30%] Meshing curve 67 (Circle)
# Info    : [ 30%] Meshing curve 68 (Circle)
# Info    : [ 30%] Meshing curve 69 (Circle)
# Info    : [ 30%] Meshing curve 70 (Circle)
# Info    : [ 30%] Meshing curve 71 (Circle)
# Info    : [ 30%] Meshing curve 72 (Circle)
# Info    : [ 30%] Meshing curve 73 (Circle)
# Info    : [ 30%] Meshing curve 74 (Circle)
# Info    : [ 30%] Meshing curve 75 (Circle)
# Info    : [ 30%] Meshing curve 76 (Circle)
# Info    : [ 30%] Meshing curve 77 (Circle)
# Info    : [ 30%] Meshing curve 78 (Circle)
# Info    : [ 30%] Meshing curve 79 (Circle)
# Info    : [ 30%] Meshing curve 80 (Circle)
# Info    : [ 30%] Meshing curve 81 (Circle)
# Info    : [ 30%] Meshing curve 82 (Circle)
# Info    : [ 30%] Meshing curve 83 (Circle)
# Info    : [ 30%] Meshing curve 84 (Circle)
# Info    : [ 30%] Meshing curve 85 (Circle)
# Info    : [ 30%] Meshing curve 86 (Circle)
# Info    : [ 30%] Meshing curve 87 (Circle)
# Info    : [ 30%] Meshing curve 88 (Circle)
# Info    : [ 30%] Meshing curve 89 (Circle)
# Info    : [ 30%] Meshing curve 90 (Circle)
# Info    : [ 30%] Meshing curve 91 (Circle)
# Info    : [ 40%] Meshing curve 92 (Circle)
# Info    : [ 40%] Meshing curve 93 (Circle)
# Info    : [ 40%] Meshing curve 94 (Circle)
# Info    : [ 40%] Meshing curve 95 (Circle)
# Info    : [ 40%] Meshing curve 96 (Circle)
# Info    : [ 40%] Meshing curve 97 (Circle)
# Info    : [ 40%] Meshing curve 98 (Circle)
# Info    : [ 40%] Meshing curve 99 (Circle)
# Info    : [ 40%] Meshing curve 100 (Circle)
# Info    : [ 40%] Meshing curve 101 (Circle)
# Info    : [ 40%] Meshing curve 102 (Circle)
# Info    : [ 40%] Meshing curve 103 (Circle)
# Info    : [ 40%] Meshing curve 104 (Circle)
# Info    : [ 40%] Meshing curve 105 (Circle)
# Info    : [ 40%] Meshing curve 106 (Circle)
# Info    : [ 40%] Meshing curve 107 (Circle)
# Info    : [ 40%] Meshing curve 108 (Circle)
# Info    : [ 40%] Meshing curve 109 (Circle)
# Info    : [ 40%] Meshing curve 110 (Circle)
# Info    : [ 40%] Meshing curve 111 (Circle)
# Info    : [ 40%] Meshing curve 112 (Circle)
# Info    : [ 40%] Meshing curve 113 (Circle)
# Info    : [ 40%] Meshing curve 114 (Circle)
# Info    : [ 40%] Meshing curve 115 (Circle)
# Info    : [ 40%] Meshing curve 116 (Circle)
# Info    : [ 40%] Meshing curve 117 (Circle)
# Info    : [ 40%] Meshing curve 118 (Circle)
# Info    : [ 40%] Meshing curve 119 (Circle)
# Info    : [ 40%] Meshing curve 120 (Circle)
# Info    : [ 40%] Meshing curve 121 (Circle)
# Info    : [ 50%] Meshing curve 122 (Circle)
# Info    : [ 50%] Meshing curve 123 (Circle)
# Info    : [ 50%] Meshing curve 124 (Circle)
# Info    : [ 50%] Meshing curve 125 (Circle)
# Info    : [ 50%] Meshing curve 126 (Circle)
# Info    : [ 50%] Meshing curve 127 (Circle)
# Info    : [ 50%] Meshing curve 128 (Circle)
# Info    : [ 50%] Meshing curve 129 (Circle)
# Info    : [ 50%] Meshing curve 130 (Circle)
# Info    : [ 50%] Meshing curve 131 (Circle)
# Info    : [ 50%] Meshing curve 132 (Circle)
# Info    : [ 50%] Meshing curve 133 (Circle)
# Info    : [ 50%] Meshing curve 134 (Circle)
# Info    : [ 50%] Meshing curve 135 (Circle)
# Info    : [ 50%] Meshing curve 136 (Circle)
# Info    : [ 50%] Meshing curve 137 (Circle)
# Info    : [ 50%] Meshing curve 138 (Circle)
# Info    : [ 50%] Meshing curve 139 (Circle)
# Info    : [ 50%] Meshing curve 140 (Circle)
# Info    : [ 50%] Meshing curve 141 (Circle)
# Info    : [ 50%] Meshing curve 142 (Circle)
# Info    : [ 50%] Meshing curve 143 (Circle)
# Info    : [ 50%] Meshing curve 144 (Circle)
# Info    : [ 50%] Meshing curve 145 (Circle)
# Info    : [ 50%] Meshing curve 146 (Circle)
# Info    : [ 50%] Meshing curve 147 (Circle)
# Info    : [ 50%] Meshing curve 148 (Circle)
# Info    : [ 50%] Meshing curve 149 (Circle)
# Info    : [ 50%] Meshing curve 150 (Circle)
# Info    : [ 50%] Meshing curve 151 (Circle)
# Info    : [ 60%] Meshing curve 152 (Circle)
# Info    : [ 60%] Meshing curve 153 (Circle)
# Info    : [ 60%] Meshing curve 154 (Circle)
# Info    : [ 60%] Meshing curve 155 (Circle)
# Info    : [ 60%] Meshing curve 156 (Circle)
# Info    : [ 60%] Meshing curve 157 (Circle)
# Info    : [ 60%] Meshing curve 158 (Circle)
# Info    : [ 60%] Meshing curve 159 (Circle)
# Info    : [ 60%] Meshing curve 160 (Circle)
# Info    : [ 60%] Meshing curve 161 (Circle)
# Info    : [ 60%] Meshing curve 162 (Circle)
# Info    : [ 60%] Meshing curve 163 (Circle)
# Info    : [ 60%] Meshing curve 164 (Circle)
# Info    : [ 60%] Meshing curve 165 (Circle)
# Info    : [ 60%] Meshing curve 166 (Circle)
# Info    : [ 60%] Meshing curve 167 (Circle)
# Info    : [ 60%] Meshing curve 168 (Circle)
# Info    : [ 60%] Meshing curve 169 (Circle)
# Info    : [ 60%] Meshing curve 170 (Circle)
# Info    : [ 60%] Meshing curve 171 (Circle)
# Info    : [ 60%] Meshing curve 172 (Circle)
# Info    : [ 60%] Meshing curve 173 (Circle)
# Info    : [ 60%] Meshing curve 174 (Circle)
# Info    : [ 60%] Meshing curve 175 (Circle)
# Info    : [ 60%] Meshing curve 176 (Circle)
# Info    : [ 60%] Meshing curve 177 (Circle)
# Info    : [ 60%] Meshing curve 178 (Circle)
# Info    : [ 60%] Meshing curve 179 (Circle)
# Info    : [ 60%] Meshing curve 180 (Circle)
# Info    : [ 60%] Meshing curve 181 (Circle)
# Info    : [ 70%] Meshing curve 182 (Circle)
# Info    : [ 70%] Meshing curve 183 (Circle)
# Info    : [ 70%] Meshing curve 184 (Circle)
# Info    : [ 70%] Meshing curve 185 (Circle)
# Info    : [ 70%] Meshing curve 186 (Circle)
# Info    : [ 70%] Meshing curve 187 (Circle)
# Info    : [ 70%] Meshing curve 188 (Circle)
# Info    : [ 70%] Meshing curve 189 (Circle)
# Info    : [ 70%] Meshing curve 190 (Circle)
# Info    : [ 70%] Meshing curve 191 (Circle)
# Info    : [ 70%] Meshing curve 192 (Circle)
# Info    : [ 70%] Meshing curve 193 (Circle)
# Info    : [ 70%] Meshing curve 194 (Circle)
# Info    : [ 70%] Meshing curve 195 (Circle)
# Info    : [ 70%] Meshing curve 196 (Circle)
# Info    : [ 70%] Meshing curve 197 (Circle)
# Info    : [ 70%] Meshing curve 198 (Circle)
# Info    : [ 70%] Meshing curve 199 (Circle)
# Info    : [ 70%] Meshing curve 200 (Circle)
# Info    : [ 70%] Meshing curve 201 (Circle)
# Info    : [ 70%] Meshing curve 202 (Circle)
# Info    : [ 70%] Meshing curve 203 (Circle)
# Info    : [ 70%] Meshing curve 204 (Circle)
# Info    : [ 70%] Meshing curve 205 (Circle)
# Info    : [ 70%] Meshing curve 206 (Circle)
# Info    : [ 70%] Meshing curve 207 (Circle)
# Info    : [ 70%] Meshing curve 208 (Circle)
# Info    : [ 70%] Meshing curve 209 (Circle)
# Info    : [ 70%] Meshing curve 210 (Circle)
# Info    : [ 70%] Meshing curve 211 (Circle)
# Info    : [ 80%] Meshing curve 212 (Circle)
# Info    : [ 80%] Meshing curve 213 (Circle)
# Info    : [ 80%] Meshing curve 214 (Circle)
# Info    : [ 80%] Meshing curve 215 (Circle)
# Info    : [ 80%] Meshing curve 216 (Circle)
# Info    : [ 80%] Meshing curve 217 (Circle)
# Info    : [ 80%] Meshing curve 218 (Circle)
# Info    : [ 80%] Meshing curve 219 (Circle)
# Info    : [ 80%] Meshing curve 220 (Circle)
# Info    : [ 80%] Meshing curve 221 (Circle)
# Info    : [ 80%] Meshing curve 222 (Circle)
# Info    : [ 80%] Meshing curve 223 (Circle)
# Info    : [ 80%] Meshing curve 224 (Circle)
# Info    : [ 80%] Meshing curve 225 (Circle)
# Info    : [ 80%] Meshing curve 226 (Circle)
# Info    : [ 80%] Meshing curve 227 (Circle)
# Info    : [ 80%] Meshing curve 228 (Circle)
# Info    : [ 80%] Meshing curve 229 (Circle)
# Info    : [ 80%] Meshing curve 230 (Circle)
# Info    : [ 80%] Meshing curve 231 (Circle)
# Info    : [ 80%] Meshing curve 232 (Circle)
# Info    : [ 80%] Meshing curve 233 (Circle)
# Info    : [ 80%] Meshing curve 234 (Circle)
# Info    : [ 80%] Meshing curve 235 (Circle)
# Info    : [ 80%] Meshing curve 236 (Circle)
# Info    : [ 80%] Meshing curve 237 (Circle)
# Info    : [ 80%] Meshing curve 238 (Circle)
# Info    : [ 80%] Meshing curve 239 (Circle)
# Info    : [ 80%] Meshing curve 240 (Circle)
# Info    : [ 80%] Meshing curve 241 (Circle)
# Info    : [ 90%] Meshing curve 242 (Circle)
# Info    : [ 90%] Meshing curve 243 (Circle)
# Info    : [ 90%] Meshing curve 244 (Circle)
# Info    : [ 90%] Meshing curve 245 (Circle)
# Info    : [ 90%] Meshing curve 246 (Circle)
# Info    : [ 90%] Meshing curve 247 (Circle)
# Info    : [ 90%] Meshing curve 248 (Circle)
# Info    : [ 90%] Meshing curve 249 (Circle)
# Info    : [ 90%] Meshing curve 250 (Circle)
# Info    : [ 90%] Meshing curve 251 (Circle)
# Info    : [ 90%] Meshing curve 252 (Circle)
# Info    : [ 90%] Meshing curve 253 (Circle)
# Info    : [ 90%] Meshing curve 254 (Circle)
# Info    : [ 90%] Meshing curve 255 (Circle)
# Info    : [ 90%] Meshing curve 256 (Circle)
# Info    : [ 90%] Meshing curve 257 (Circle)
# Info    : [ 90%] Meshing curve 258 (Circle)
# Info    : [ 90%] Meshing curve 259 (Circle)
# Info    : [ 90%] Meshing curve 260 (Circle)
# Info    : [ 90%] Meshing curve 261 (Circle)
# Info    : [ 90%] Meshing curve 262 (Circle)
# Info    : [ 90%] Meshing curve 263 (Circle)
# Info    : [ 90%] Meshing curve 264 (Circle)
# Info    : [ 90%] Meshing curve 265 (Circle)
# Info    : [ 90%] Meshing curve 266 (Circle)
# Info    : [ 90%] Meshing curve 267 (Circle)
# Info    : [ 90%] Meshing curve 268 (Circle)
# Info    : [ 90%] Meshing curve 269 (Circle)
# Info    : [ 90%] Meshing curve 270 (Circle)
# Info    : [ 90%] Meshing curve 271 (Circle)
# Info    : [100%] Meshing curve 272 (Circle)
# Info    : [100%] Meshing curve 273 (Circle)
# Info    : [100%] Meshing curve 274 (Circle)
# Info    : [100%] Meshing curve 275 (Circle)
# Info    : [100%] Meshing curve 276 (Circle)
# Info    : [100%] Meshing curve 277 (Circle)
# Info    : [100%] Meshing curve 278 (Circle)
# Info    : [100%] Meshing curve 279 (Circle)
# Info    : [100%] Meshing curve 280 (Circle)
# Info    : [100%] Meshing curve 281 (Circle)
# Info    : [100%] Meshing curve 282 (Circle)
# Info    : [100%] Meshing curve 283 (Circle)
# Info    : [100%] Meshing curve 284 (Circle)
# Info    : [100%] Meshing curve 285 (Circle)
# Info    : [100%] Meshing curve 286 (Circle)
# Info    : [100%] Meshing curve 287 (Circle)
# Info    : [100%] Meshing curve 288 (Circle)
# Info    : [100%] Meshing curve 289 (Circle)
# Info    : [100%] Meshing curve 290 (Circle)
# Info    : [100%] Meshing curve 291 (Circle)
# Info    : [100%] Meshing curve 292 (Circle)
# Info    : [100%] Meshing curve 293 (Circle)
# Info    : [100%] Meshing curve 294 (Circle)
# Info    : [100%] Meshing curve 295 (Circle)
# Info    : [100%] Meshing curve 296 (Circle)
# Info    : [100%] Meshing curve 297 (Circle)
# Info    : [100%] Meshing curve 298 (Circle)
# Info    : [100%] Meshing curve 299 (Circle)
# Info    : [100%] Meshing curve 300 (Circle)
# Info    : [100%] Meshing curve 301 (Circle)
# Info    : Done meshing 1D (Wall 0.0239716s, CPU 0.028165s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Delaunay)
# Info    : Blossom: 19314 internal 3576 closed
# Info    : Blossom recombination completed (Wall 0.811605s, CPU 0.810214s): 6884 quads, 46 triangles, 0 invalid quads, 0 quads with Q < 0.1, avg Q = 0.684013, min Q = 0.104271
# Info    : Done meshing 2D (Wall 1.50922s, CPU 1.50901s)
# Info    : 8399 nodes 10807 elements
