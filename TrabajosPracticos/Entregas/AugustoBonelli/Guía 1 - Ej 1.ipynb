# %%
import numpy as np 
import matplotlib.pyplot as plt
import time

font = {'family' : 'monospace',
        #'weight' : 'bold',
        'size'   : 20}
plt.rc('figure', figsize=(16,9))
plt.rc('font', **font)  # pass in the font dict as kwargs
plt.rc('lines', lw=2)

# %%
def chapa(Nx, Ny, cc, cc_tipo):
    beta = Nx/Ny
    Nk = Nx*Ny

    M = np.eye(Nk)
    b = np.zeros((Nk, 1))

    # Condiciones de contorno
    ccA = list(range(0, Nk, Nx))
    ccB = list(range(0,Nx))
    ccC = list(range(Nx-1, Nk, Ny))
    ccD = list(range(Nk-Nx,Nk))

    for k in range(Nk):
        # Vertice A-B
        if k==0:
            if cc_tipo['A']=='temp'  and cc_tipo['B'] == 'flujo':
                print('lelele')
                b[k] = TC['A']
            elif cc_tipo['B']=='temp'  and cc_tipo['A'] == 'flujo':
                print('lilili')
                b[k] = TC['B']
            elif cc_tipo['B']=='temp'  and cc_tipo['A'] == 'temp':
                print('lalala')
                b[k]= (TC['A']+TC['B'])/2

        # Vértice B-C
        elif k==(Nx-1): # En los vértices siempre nos quedamos con el borde que tiene temperatura fija.
            if cc_tipo['B']=='temp'  and cc_tipo['C'] == 'flujo':
                print('jijiji')
                b[k] = TC['B']
            elif cc_tipo['C']=='temp'  and cc_tipo['B'] == 'flujo':
                print('jejeje')
                b[k] = TC['C']
            elif cc_tipo['B']=='temp'  and cc_tipo['C'] == 'temp':
                print('jojojo')
                b[k]= (TC['C']+TC['B'])/2

        # Vértice C-D
        elif k==Nk-1:
            if cc_tipo['C']=='temp'  and cc_tipo['D'] == 'flujo':
                b[k] = TC['C']
            elif cc_tipo['D']=='temp'  and cc_tipo['C'] == 'flujo':
                b[k] = TC['D']
            elif cc_tipo['D']=='temp'  and cc_tipo['C'] == 'temp':
                b[k]= (TC['C']+TC['D'])/2

        # Vértice D-A
        elif k==Nk-1:
            if cc_tipo['A']=='temp'  and cc_tipo['D'] == 'flujo':
                b[k] = TC['A']
            elif cc_tipo['D']=='temp'  and cc_tipo['A'] == 'flujo':
                b[k] = TC['D']
            elif cc_tipo['D']=='temp'  and cc_tipo['A'] == 'temp':
                b[k]= (TC['A']+TC['D'])/2
            

        elif k in ccA:
            if cc_tipo['A'] == 'temp':
                b[k] = TC['A']
            elif cc_tipo['A'] == 'flujo':
                M[k,k] = -2*(1+beta**2)
                M[k,k+1] = 2
                M[k,k-Nx] = beta**2
                M[k,k+Nx] = beta**2

        elif k in ccB:
            if cc_tipo['B'] == 'temp':
                b[k] = TC['B']
            elif cc_tipo['B'] == 'flujo':
                print('lololo')
                M[k,k] = -2*(1+beta**2)
                M[k,k+1] = 1
                M[k,k+1] = 1
#                M[k,k+Nx] = beta**2 te faltaba un dos aca
                M[k,k+Nx] = 2*beta**2 

        elif k in ccC:
            if cc_tipo['C'] == 'temp':
                b[k] = TC['C']
            elif cc_tipo['C'] == 'flujo':
                M[k,k] = -2*(1+beta**2)
                M[k,k-1] = 2
                M[k,k-Nx] = beta**2
                M[k,k+Nx] = beta**2

        elif k in ccD:
            if cc_tipo['D'] == 'temp':
                b[k] = TC['D']
            elif cc_tipo['D'] == 'flujo':
                M[k,k] = -2*(1+beta**2)
                M[k,k-1] = 1
                M[k,k+1] = 1
                M[k,k-Nx] = 2*beta**2

        # Interior
        else:
            M[k,k]= -2*(1+ beta**2)
            M[k,k-1]= 1
            M[k,k+1]= 1
            M[k,k-Nx]= beta**2
            M[k,k+Nx]= beta**2
            
    T = np.linalg.solve(M,b)
    return T

# %%
Nx = 10
Ny = 10


TC = {'A':75, 'B':0 , 'C':50, 'D':100}
# cc_tipo = {'A':'temp','B':'temp','C':'temp','D':'temp'} Hiciste tb con flujo ?
cc_tipo = {'A':'temp','B':'flujo','C':'temp','D':'temp'}
# no me estaría funcionando si le pongo cc de flujo

T = chapa(Nx, Ny, TC, cc_tipo)

T_plot = T.reshape((Nx,Ny)) 
s = plt.imshow(T_plot, origin= 'lower')
plt.colorbar(s)
fig, ax = plt.subplots()
mappable = ax.contourf(T_plot)
levels = ax.contour(T_plot, colors='k', linewidths=5)
cbar = plt.colorbar(mappable)
cbar.set_label('T (ºC)')
ax.clabel(levels, )
ax.set_xlabel('i')
ax.set_ylabel('j')
# Out:
# lelele
# lololo
# lololo
# lololo
# lololo
# lololo
# lololo
# lololo
# lololo
# jejeje
# Text(0, 0.5, 'j')

# %% [markdown]
# <div style="background:#999900">traté de debuguearlo per no me anda con condiciones de flujo, algo raro hay. No importa, debe ser un detalle qe por algun motivo no anda. </div>

# %%
def performance(Nxs, Nys, TC, cc_tipo):
    N = len(Nxs)
    ts = np.zeros_like(Nxs).astype(float)
    
    for i in range(N):
        t0 = time.time()
        chapa(Nxs[i], Nys[i], TC, cc_tipo)
        t1 = time.time()
        ts[i] = t1-t0
#         print(ts)
    return ts 


Nxs = Nys = np.linspace(5,100, 20).astype(int)
TC = {'A':75, 'B':0 , 'C':50, 'D':100}
cc_tipo = {'A':'temp','B':'temp','C':'temp','D':'temp'}

ts = performance(Nxs, Nys, TC, cc_tipo)
# Out:
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo
# lalala
# jojojo

# %%
plt.plot(Nxs, ts, 'o', markersize= 10)
plt.grid()
plt.title('Performance')
plt.xlabel('Cantidad de nodos')
plt.ylabel('Tiempo (s)')
# Out:
# Text(0, 0.5, 'Tiempo (s)')

# %% [markdown]
# <div style="background:#999900">Estos tiempos los podes graficar en escala log para que se vea mejor:</div>

# %%
plt.plot(Nxs, ts, 'o', markersize= 10)
plt.grid()
plt.title('Performance')
plt.xlabel('Cantidad de nodos')
plt.ylabel('Tiempo (s)')
plt.yscale('log')
plt.yscale('log')

# %% [markdown]
# <div style="background:#999900">y ahora se ve que hay una relación exponencial entre el tiempo y el tamaño del istema. podríamos ir más alla. fiteando esa relación lineal podes ver que es mas rápido que la cantidad de operaciones para la inversión de la matrix ($N^3$) debido a la paralelización que hacen las compus modernas</div>

# %% [markdown]
# <div style="background:#999900">Fiteando por una lineal:</div>

# %%
Coeff = np.polyfit(np.log10(Nxs), np.log10(ts), 1)

# %%
Coeff
# Out:
# array([ 3.39568055, -6.612155  ])

# %% [markdown]
# <div style="background:#999900">se ve que el exponente en la relacón es (en mi pc) casi la mitad de lo esperado que era $Nx^6$</div>
